# %%
import numpy as np
from pylab import *
import scipy
import pandas as pd
import datetime
from scipy import optimize

growth_curves = pd.read_excel (r'bAG24_plate_layout_2_Chl-0-3-6-9-12uM.xlsx', sheet_name='Sheet1')

strain_name='ecAG24'

start=datetime.time(0,0,0)
measure_times=[(datetime.datetime.combine(datetime.date.today(), growth_curves['Time'][i])- datetime.datetime.combine(datetime.date.today(), start)).total_seconds() / 3600  for i in range(len(growth_curves))]

# %%
I0_C0=['A6','B11','C8','D1','D10','E3','F6','G12','H1']
I0_C3=['B1','B12','F5']
I0_C6=['C4','F2','H9']
I0_C9=['A2','F10','H6']
I0_C12=['A12','D4','E8']

I20_C0=['C9','E12','G3']
I20_C3=['B7','C2','E6']
I20_C6=['C6','D3','F12']
I20_C9=['C11','D5','G8']
I20_C12=['E1','F7','H5']

I40_C0=['C12','D7','G1']
I40_C3=['A9','E4','H11']
I40_C6=['A5','C10','F9']
I40_C9=['B4','E11','H12']
I40_C12=['A11','B3','D6']

I60_C0=['D11','F8','H10']
I60_C3=['B5','E9','G7']
I60_C6=['B8','G11','H4']
I60_C9=['B9','E7','F1']
I60_C12=['C7','D2','D12']

I80_C0=['A10','C5','E5']
I80_C3=['A3','D8','F11']
I80_C6=['C1','E10','F3']
I80_C9=['A1','G5','H8']
I80_C12=['C3','F4','H2']

I100_C0=['A4','G2','H3']
I100_C3=['G4','G9','H7']
I100_C6=['A8','B2','G6']
I100_C9=['B6','B10','E2']
I100_C12=['A7','D9','G10']

IPTG_0=[['A6','B11','C8','D1','D10','E3','F6','G12','H1'],['B1','B12','F5'],['C4','F2','H9'],['A2','F10','H6'],['A12','D4','E8']]
IPTG_20=[['C9','E12','G3'],['B7','C2','E6'],['C6','D3','F12'],['C11','D5','G8'],['E1','F7','H5']]
IPTG_40=[['C12','D7','G1'],['A9','E4','H11'],['A5','C10','F9'],['B4','E11','H12'],['A11','B3','D6']]
IPTG_60=[['D11','F8','H10'],['B5','E9','G7'],['B8','G11','H4'],['B9','E7','F1'],['C7','D2','D12']]
IPTG_80=[['A10','C5','E5'],['A3','D8','F11'],['C1','E10','F3'],['A1','G5','H8'],['C3','F4','H2']]
IPTG_100=[['A4','G2','H3'],['G4','G9','H7'],['A8','B2','G6'],['B6','B10','E2'],['A7','D9','G10']]


curves_IPTG_0=[np.log(growth_curves.loc[:, I0_C0]),np.log(growth_curves.loc[:, I0_C3]),np.log(growth_curves.loc[:, I0_C6]),np.log(growth_curves.loc[:, I0_C9]),np.log(growth_curves.loc[:, I0_C12])]
curves_IPTG_20=[np.log(growth_curves.loc[:, I20_C0]),np.log(growth_curves.loc[:, I20_C3]),np.log(growth_curves.loc[:, I20_C6]),np.log(growth_curves.loc[:, I20_C9]),np.log(growth_curves.loc[:, I20_C12])]
curves_IPTG_40=[np.log(growth_curves.loc[:, I40_C0]),np.log(growth_curves.loc[:, I40_C3]),np.log(growth_curves.loc[:, I40_C6]),np.log(growth_curves.loc[:, I40_C9]),np.log(growth_curves.loc[:, I40_C12])]
curves_IPTG_60=[np.log(growth_curves.loc[:, I60_C0]),np.log(growth_curves.loc[:, I60_C3]),np.log(growth_curves.loc[:, I60_C6]),np.log(growth_curves.loc[:, I60_C9]),np.log(growth_curves.loc[:, I60_C12])]
curves_IPTG_80=[np.log(growth_curves.loc[:, I80_C0]),np.log(growth_curves.loc[:, I80_C3]),np.log(growth_curves.loc[:, I80_C6]),np.log(growth_curves.loc[:, I80_C9]),np.log(growth_curves.loc[:, I80_C12])]
curves_IPTG_100=[np.log(growth_curves.loc[:, I100_C0]),np.log(growth_curves.loc[:, I100_C3]),np.log(growth_curves.loc[:, I100_C6]),np.log(growth_curves.loc[:, I100_C9]),np.log(growth_curves.loc[:, I100_C12])]

IPTG_concs=[0,20,40,60,80,100]
Chl_concs=[0,3,6,9,12]

# %%
fig = plt.figure(figsize=(25,15))
fig.suptitle('IPTG 0 uM', fontsize=22)
fig.subplots_adjust(hspace=0.4, wspace=0.25)
for i in range(len(Chl_concs)):
    subplot = fig.add_subplot(2, 4, i+1)
    subplot.plot(measure_times,curves_IPTG_0[i])
    subplot.set_xlabel('Time (hours)')
    subplot.set_ylabel('OD600')
    subplot.set_title('Chl '+str(Chl_concs[i])+' uM')
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
fig.suptitle('IPTG 20 uM', fontsize=22)
fig.subplots_adjust(hspace=0.4, wspace=0.25)
for i in range(len(Chl_concs)):
    subplot = fig.add_subplot(2, 4, i+1)
    subplot.plot(measure_times,curves_IPTG_20[i])
    subplot.set_xlabel('Time (hours)')
    subplot.set_ylabel('OD600')
    subplot.set_title('Chl '+str(Chl_concs[i])+' uM')
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
fig.suptitle('IPTG 40 uM', fontsize=22)
fig.subplots_adjust(hspace=0.4, wspace=0.25)
for i in range(len(Chl_concs)):
    subplot = fig.add_subplot(2, 4, i+1)
    subplot.plot(measure_times,curves_IPTG_40[i])
    subplot.set_xlabel('Time (hours)')
    subplot.set_ylabel('OD600')
    subplot.set_title('Chl '+str(Chl_concs[i])+' uM')
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
fig.suptitle('IPTG 60 uM', fontsize=22)
fig.subplots_adjust(hspace=0.4, wspace=0.25)
for i in range(len(Chl_concs)):
    subplot = fig.add_subplot(2, 4, i+1)
    subplot.plot(measure_times,curves_IPTG_60[i])
    subplot.set_xlabel('Time (hours)')
    subplot.set_ylabel('OD600')
    subplot.set_title('Chl '+str(Chl_concs[i])+' uM')
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
fig.suptitle('IPTG 80 uM', fontsize=22)
fig.subplots_adjust(hspace=0.4, wspace=0.25)
for i in range(len(Chl_concs)):
    subplot = fig.add_subplot(2, 4, i+1)
    subplot.plot(measure_times,curves_IPTG_80[i])
    subplot.set_xlabel('Time (hours)')
    subplot.set_ylabel('OD600')
    subplot.set_title('Chl '+str(Chl_concs[i])+' uM')
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
fig.suptitle('IPTG 100 uM', fontsize=22)
fig.subplots_adjust(hspace=0.4, wspace=0.25)
for i in range(len(Chl_concs)):
    subplot = fig.add_subplot(2, 4, i+1)
    subplot.plot(measure_times,curves_IPTG_100[i])
    subplot.set_xlabel('Time (hours)')
    subplot.set_ylabel('OD600')
    subplot.set_title('Chl '+str(Chl_concs[i])+' uM')
plt.show()

# %%
range_inf=5
range_sup=15

I=0
while 1:
    if measure_times[I]<=range_inf:
        I=I+1
    else:
        break
        
J=0
while 1:
    if measure_times[J]<=range_sup:
        J=J+1
    else:
        break

# %%
growth_I0_C0=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_0[0][I:J].T.values[j])[0][1] for j in range(len(IPTG_0[0]))]

growth_I0_C3=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_0[1][I:J].T.values[j])[0][1] for j in range(len(IPTG_0[1]))]

growth_I0_C6=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_0[2][I:J].T.values[j])[0][1] for j in range(len(IPTG_0[2]))]

growth_I0_C9=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_0[3][I:J].T.values[j])[0][1] for j in range(len(IPTG_0[3]))]

growth_I0_C12=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_0[4][I:J].T.values[j])[0][1] for j in range(len(IPTG_0[4]))]


growth_I20_C0=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_20[0][I:J].T.values[j])[0][1] for j in range(len(IPTG_20[0]))]

growth_I20_C3=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_20[1][I:J].T.values[j])[0][1] for j in range(len(IPTG_20[1]))]

growth_I20_C6=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_20[2][I:J].T.values[j])[0][1] for j in range(len(IPTG_20[2]))]

growth_I20_C9=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_20[3][I:J].T.values[j])[0][1] for j in range(len(IPTG_20[3]))]

growth_I20_C12=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_20[4][I:J].T.values[j])[0][1] for j in range(len(IPTG_20[4]))]


growth_I40_C0=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_40[0][I:J].T.values[j])[0][1] for j in range(len(IPTG_40[0]))]

growth_I40_C3=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_40[1][I:J].T.values[j])[0][1] for j in range(len(IPTG_40[1]))]

growth_I40_C6=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_40[2][I:J].T.values[j])[0][1] for j in range(len(IPTG_40[2]))]

growth_I40_C9=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_40[3][I:J].T.values[j])[0][1] for j in range(len(IPTG_40[3]))]

growth_I40_C12=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_40[4][I:J].T.values[j])[0][1] for j in range(len(IPTG_40[4]))]


growth_I60_C0=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_60[0][I:J].T.values[j])[0][1] for j in range(len(IPTG_60[0]))]

growth_I60_C3=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_60[1][I:J].T.values[j])[0][1] for j in range(len(IPTG_60[1]))]

growth_I60_C6=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_60[2][I:J].T.values[j])[0][1] for j in range(len(IPTG_60[2]))]

growth_I60_C9=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_60[3][I:J].T.values[j])[0][1] for j in range(len(IPTG_60[3]))]

growth_I60_C12=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_60[4][I:J].T.values[j])[0][1] for j in range(len(IPTG_60[4]))]


growth_I80_C0=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_80[0][I:J].T.values[j])[0][1] for j in range(len(IPTG_80[0]))]

growth_I80_C3=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_80[1][I:J].T.values[j])[0][1] for j in range(len(IPTG_80[1]))]

growth_I80_C6=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_80[2][I:J].T.values[j])[0][1] for j in range(len(IPTG_80[2]))]

growth_I80_C9=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_80[3][I:J].T.values[j])[0][1] for j in range(len(IPTG_80[3]))]

growth_I80_C12=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_80[4][I:J].T.values[j])[0][1] for j in range(len(IPTG_80[4]))]


growth_I100_C0=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_100[0][I:J].T.values[j])[0][1] for j in range(len(IPTG_100[0]))]

growth_I100_C3=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_100[1][I:J].T.values[j])[0][1] for j in range(len(IPTG_100[1]))]

growth_I100_C6=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_100[2][I:J].T.values[j])[0][1] for j in range(len(IPTG_100[2]))]

growth_I100_C9=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_100[3][I:J].T.values[j])[0][1] for j in range(len(IPTG_100[3]))]

growth_I100_C12=[scipy.optimize.curve_fit(lambda t,a,b: a+b*t, measure_times[I:J],curves_IPTG_100[4][I:J].T.values[j])[0][1] for j in range(len(IPTG_100[4]))]

# %%
growth_IPTG_0=[growth_I0_C0,growth_I0_C3,growth_I0_C6,growth_I0_C9,growth_I0_C12]

growth_IPTG_20=[growth_I20_C0,growth_I20_C3,growth_I20_C6,growth_I20_C9,growth_I20_C12]

growth_IPTG_40=[growth_I40_C0,growth_I40_C3,growth_I40_C6,growth_I40_C9,growth_I40_C12]

growth_IPTG_60=[growth_I60_C0,growth_I60_C3,growth_I60_C6,growth_I60_C9,growth_I60_C12]

growth_IPTG_80=[growth_I80_C0,growth_I80_C3,growth_I80_C6,growth_I80_C9,growth_I80_C12]

growth_IPTG_100=[growth_I100_C0,growth_I100_C3,growth_I100_C6,growth_I100_C9,growth_I100_C12]

# %%
growth_IPTG_boxplots=[growth_IPTG_0,growth_IPTG_20,growth_IPTG_40,growth_IPTG_60,growth_IPTG_80,growth_IPTG_100]

fig = plt.figure(figsize=(25,15))
fig.suptitle('Box plots - Growth rates', fontsize=22)
fig.subplots_adjust(hspace=0.4, wspace=0.25)
for i in range(len(IPTG_concs)):
    subplot = fig.add_subplot(2,3,i+1)
    subplot.boxplot(growth_IPTG_boxplots[i])
    subplot.set_title('IPTG '+str(IPTG_concs[i])+' uM', fontsize=20)
    subplot.set_xlabel('Chloramphenicol concentration (uM)', fontsize=15)
    subplot.set_ylabel(strain_name+' growth rate (1/h)', fontsize=15)
    subplot.set_xticks([1,2,3,4,5])
    subplot.set_xticklabels(Chl_concs)
plt.show()
